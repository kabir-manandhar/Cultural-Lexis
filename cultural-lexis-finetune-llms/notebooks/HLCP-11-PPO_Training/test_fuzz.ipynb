# %%
from thefuzz import fuzz

# %%
en_example_1 = {"output": "ghost, scare, halloween, scary, surprise",
                "prediction": "scary, ghost, scare"}

en_example_2 = {"output": "ghost, scare, halloween, scary, surprise",
                "prediction": "scary, ghost, scare, otherthing"}


en_example_3 = {"output": "ghost, scare, halloween, scary, surprise",
                "prediction": "scary, ghost, otherthing"}

en_example_4 = {"output": "ghost, scare, halloween, scary, surprise",
                "prediction": "scary, otherthing, ghost"}
# eg1 and eg2's score should be the same 

print(fuzz.token_sort_ratio(en_example_1["prediction"], en_example_1["output"]))
print(fuzz.token_sort_ratio(en_example_2["prediction"], en_example_2["output"]))

# eg3's score should be lower than eg1 and eg2
print(fuzz.token_sort_ratio(en_example_3["prediction"], en_example_3["output"]))
# eg4's score should be lower than eg1 and eg2
print(fuzz.token_sort_ratio(en_example_4["prediction"], en_example_4["output"]))
# Out:
# 64
# 66
# 52
# 52

# %%
# test chinese version 
zh_example_1 = {"output": "鬼, 吓人, 万圣节, 可怕, 惊喜",
                "prediction": "可怕, 鬼, 吓人"}

zh_example_2 = {"output": "鬼,吓人,万圣节,可怕,惊喜",
                "prediction": "可怕,鬼,吓人,其他"}

zh_example_3 = {"output": "鬼,吓人,万圣节,可怕,惊喜",
                "prediction": "可怕,鬼,其他"}

zh_example_4 = {"output": "鬼,吓人,万圣节,可怕,惊喜",
                "prediction": "可怕,其他,鬼"}

zh_example_5 = {"output": "鬼, 吓人, 万圣节, 可怕, 惊喜",
                "prediction": "鬼, 可怕, 其他"}

print(fuzz.token_sort_ratio(zh_example_1["prediction"], zh_example_1["output"]))
print(fuzz.token_sort_ratio(zh_example_2["prediction"], zh_example_2["output"]))

# eg3's score should be lower than eg1 and eg2
print(fuzz.token_sort_ratio(zh_example_3["prediction"], zh_example_3["output"]))
# eg4's score should be lower than eg1 and eg2
print(fuzz.token_sort_ratio(zh_example_4["prediction"], zh_example_4["output"]))
# eg5's score should be the same as eg1 and eg2
print(fuzz.token_sort_ratio(zh_example_5["prediction"], zh_example_5["output"]))
# Out:
# 67
# 67
# 48
# 48
# 48

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-7B-Instruct")
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.1-8B")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]

# %%
tokenizer.chat_template

# %%
prompt = "Give me a short introduction to large language model."
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 6
#       1 prompt = "Give me a short introduction to large language model."
#       2 messages = [
#       3     {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
#       4     {"role": "user", "content": prompt}
#       5 ]
# ----> 6 text = tokenizer.apply_chat_template(
#       7     messages,
#       8     tokenize=False,
#       9     add_generation_prompt=True
#      10 )
#
# File ~/anaconda3/envs/pftkedro/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1803, in PreTrainedTokenizerBase.apply_chat_template(self, conversation, tools, documents, chat_template, add_generation_prompt, continue_final_message, tokenize, padding, truncation, max_length, return_tensors, return_dict, return_assistant_tokens_mask, tokenizer_kwargs, **kwargs)
#    1800 if tokenizer_kwargs is None:
#    1801     tokenizer_kwargs = {}
# -> 1803 chat_template = self.get_chat_template(chat_template, tools)
#    1805 if return_assistant_tokens_mask and not re.search(r"\{\%-?\s*generation\s*-?\%\}", chat_template):
#    1806     logger.warning_once(
#    1807         "return_assistant_tokens_mask==True but chat template does not contain `{% generation %}` keyword."
#    1808     )
#
# File ~/anaconda3/envs/pftkedro/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1967, in PreTrainedTokenizerBase.get_chat_template(self, chat_template, tools)
#    1965         chat_template = self.chat_template
#    1966     else:
# -> 1967         raise ValueError(
#    1968             "Cannot use chat template functions because tokenizer.chat_template is not set and no template "
#    1969             "argument was passed! For information about writing templates and setting the "
#    1970             "tokenizer.chat_template attribute, please see the documentation at "
#    1971             "https://huggingface.co/docs/transformers/main/en/chat_templating"
#    1972         )
#    1974 return chat_template
#
# ValueError: Cannot use chat template functions because tokenizer.chat_template is not set and no template argument was passed! For information about writing templates and setting the tokenizer.chat_template attribute, please see the documentation at https://huggingface.co/docs/transformers/main/en/chat_templating

# %%
text
# Out:
# '<|im_start|>system\nYou are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>\n<|im_start|>user\nGive me a short introduction to large language model.<|im_end|>\n<|im_start|>assistant\n'
